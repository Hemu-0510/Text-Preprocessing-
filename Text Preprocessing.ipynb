# %%
import pandas as pd
import re

# Read raw CSV
df = pd.read_csv("raw_text.csv", encoding="utf-8-sig")

# Text preprocessing function
def clean_text(text):

    # Convert to lowercase
    text = str(text).lower()

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', ' ', text)

    # Remove email addresses
    text = re.sub(r'\b[\w.+-]+@[\w.-]+\.[a-zA-Z]{2,}\b', ' ', text)

    # Remove phone numbers
    text = re.sub(r'\b\d{10}\b', ' ', text)

    # Remove HTML tags
    text = re.sub(r'<[^>]*>', ' ', text)

    # Remove @mentions
    text = re.sub(r'@\w+', ' ', text)

    # Remove hashtag symbol
    text = re.sub(r'#', '', text)

    # Remove emojis
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)

    # Remove punctuation and numbers
    text = re.sub(r'[^a-zA-Z\s]', ' ', text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# Apply preprocessing
df["Clean_Conversation"] = df["Conversation"].apply(clean_text)

# Display result
print("Preprocessing Completed Successfully!")
print(df)

# Save cleaned CSV
df.to_csv(
    "cleaned_text.csv",
    index=False,
    encoding="utf-8-sig",
    lineterminator="\n"
)

print("\nCleaned CSV file created successfully!")
# Out:
# Preprocessing Completed Successfully!
#     ID                                       Conversation  \
# 0    1  Good morning everyone!! 👋 Have a wonderful day! 😊
# 1    2  Don't forget to submit your assignment before ...
# 2    3  Check this article: https://www.technews.com/l...
# 3    4  Contact me at arunkumar123@gmail.com for more ...
# 4    5  My mobile number is 9123456780. Please call af...
# 5    6  Happy Birthday, Priya!!! 🎂🎉 Have an amazing ye...
# 6    7           I just bought a new laptop for ₹65000. 💻
# 7    8  Follow us @DataWorld and #ArtificialIntelligen...
# 8    9  <i>Thank you</i> for visiting our website toda...
# 9   10  Wow!!! The concert was absolutely incredible!! 🎵🔥
# 10  11       Meeting starts at 2:00 PM in Room No. 205. ⏰
# 11  12  Congratulations! 🎓 You successfully completed ...
# 12  13  Order ID: #ORD56789 has been shipped successfu...
# 13  14          OMG!! 😲 I never expected this surprise! 🎁
# 14  15  Limited-time offer: Buy 2, Get 1 Free!! 🛍️ Hur...
#
#                                    Clean_Conversation
# 0          good morning everyone have a wonderful day
# 1    don t forget to submit your assignment before pm
# 2                                  check this article
# 3                  contact me at for more information
# 4            my mobile number is please call after pm
# 5     happy birthday priya have an amazing year ahead
# 6                      i just bought a new laptop for
# 7         follow us and artificialintelligence python
# 8            thank you for visiting our website today
# 9           wow the concert was absolutely incredible
# 10                    meeting starts at pm in room no
# 11  congratulations you successfully completed the...
# 12         order id ord has been shipped successfully
# 13                 omg i never expected this surprise
# 14           limited time offer buy get free hurry up
#
# Cleaned CSV file created successfully!
